# %% [markdown]
# #### Hi! Today you will play with NaN values and another Data Manipulation methods. Let us know if you need help and also if you need more challenges on that :)

# %% [markdown]
# #### The dataset that you will use is again recipes.csv. You can either use your own or the one in the subfolder "data". Do not forget to import the necessary libraries!

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
recipes = pd.read_csv('data\\recipes.csv')
recipes
# Out:
#      Unnamed: 0  vegetarian  glutenFree  dairyFree  veryHealthy  healthScore  \
# 0             0        True        True       True        False          1.0
# 1             1        True        True      False        False          0.0
# 2             2       False       False      False        False          3.0
# 3             3        True       False       True        False          2.0
# 4             4       False        True      False        False         31.0
# ..          ...         ...         ...        ...          ...          ...
# 145         145       False        True       True        False         18.0
# 146         146        True       False      False        False          1.0
# 147         147        True        True       True         True         93.0
# 148         148        True        True      False        False          5.0
# 149         149        True        True       True         True        100.0
#
#      aggregateLikes      id  \
# ...

# %% [markdown]
# #### Print the names of Columns that have null values

# %%
recipes.isna().any()[lambda x: x]
# Out:
# FiberAmount                     True
# FiberpercentOfDailyNeed         True
# VitaminB6Amount                 True
# VitaminB6percentOfDailyNeed     True
# ManganeseAmount                 True
# ManganesepercentOfDailyNeed     True
# SeleniumAmount                  True
# SeleniumpercentOfDailyNeed      True
# PotassiumAmount                 True
# PotassiumpercentOfDailyNeed     True
# VitaminB2Amount                 True
# VitaminB2percentOfDailyNeed     True
# VitaminCAmount                  True
# VitaminCpercentOfDailyNeed      True
# PhosphorusAmount                True
# PhosphoruspercentOfDailyNeed    True
# FolateAmount                    True
# FolatepercentOfDailyNeed        True
# VitaminB5Amount                 True
# VitaminB5percentOfDailyNeed     True
# MagnesiumAmount                 True
# MagnesiumpercentOfDailyNeed     True
# IronAmount                      True
# IronpercentOfDailyNeed          True
# VitaminKAmount                  True
# ...

# %% [markdown]
# #### Print the recipes with the highest number of aggregateLikes

# %%
recipes[recipes['aggregateLikes']==recipes['aggregateLikes'].max()]
# Out:
#     Unnamed: 0  vegetarian  glutenFree  dairyFree  veryHealthy  healthScore  \
# 50          50       False        True       True        False          4.0
#
#     aggregateLikes      id                        title  pricePerServing  ...  \
# 50           16911  715419  Slow Cooker Spicy Hot Wings           101.43  ...
#
#     VitaminB3Amount  VitaminB3percentOfDailyNeed VitaminB1Amount  \
# 50             7.42                        37.09            0.08
#
#     VitaminB1percentOfDailyNeed  CalciumAmount  CalciumpercentOfDailyNeed  \
# 50                          5.0          44.21                       4.42
#
#     AlcoholAmount  AlcoholpercentOfDailyNeed  CaffeineAmount  \
# 50            NaN                        NaN             NaN
#
#     CaffeinepercentOfDailyNeed
# 50                         NaN
#
# [1 rows x 79 columns]

# %% [markdown]
# #### Handle the missing values of “calcium percent of Daily need”. Sort the resulting DataFrame by id column.

# %%
recipes_copy = recipes.copy()
recipes_copy = recipes_copy[pd.notnull(recipes_copy['CalciumpercentOfDailyNeed'])]
recipes_copy

# dropped rows where values in "CalciumpercentOfDailyNeed" are NaN
# Out:
#      Unnamed: 0  vegetarian  glutenFree  dairyFree  veryHealthy  healthScore  \
# 0             0        True        True       True        False          1.0
# 2             2       False       False      False        False          3.0
# 3             3        True       False       True        False          2.0
# 4             4       False        True      False        False         31.0
# 5             5       False        True       True        False         30.0
# ..          ...         ...         ...        ...          ...          ...
# 145         145       False        True       True        False         18.0
# 146         146        True       False      False        False          1.0
# 147         147        True        True       True         True         93.0
# 148         148        True        True      False        False          5.0
# 149         149        True        True       True         True        100.0
#
#      aggregateLikes       id  \
# ...

# %%
recipes_id = recipes_copy.sort_values(by=['id'])
recipes_id
# Out:
#      Unnamed: 0  vegetarian  glutenFree  dairyFree  veryHealthy  healthScore  \
# 83           83       False       False      False        False          5.0
# 43           43       False       False      False        False         44.0
# 104         104       False       False      False        False          4.0
# 95           95       False        True       True        False          9.0
# 52           52       False       False      False        False          2.0
# ..          ...         ...         ...        ...          ...          ...
# 134         134        True        True       True         True         77.0
# 30           30        True        True       True        False         17.0
# 118         118       False        True       True        False         38.0
# 39           39        True        True       True        False          7.0
# 67           67       False        True      False        False         15.0
#
# ...

# %% [markdown]
# #### Delete the columns that have null values == 141

# %%
recipes_copy2 = recipes.copy()
recipes_copy2 = recipes_copy2.dropna(thresh=141, axis=1)
recipes_copy2
# Out:
#      Unnamed: 0  vegetarian  glutenFree  dairyFree  veryHealthy  healthScore  \
# 0             0        True        True       True        False          1.0
# 1             1        True        True      False        False          0.0
# 2             2       False       False      False        False          3.0
# 3             3        True       False       True        False          2.0
# 4             4       False        True      False        False         31.0
# ..          ...         ...         ...        ...          ...          ...
# 145         145       False        True       True        False         18.0
# 146         146        True       False      False        False          1.0
# 147         147        True        True       True         True         93.0
# 148         148        True        True      False        False          5.0
# 149         149        True        True       True         True        100.0
#
#      aggregateLikes      id  \
# ...

# %% [markdown]
# #### Print the title of the recipes that are vegetarian == TRUE and glutenFree == True

# %%
recipes_v_gf = recipes.loc[((recipes['vegetarian'] == True) & (recipes['glutenFree'] == True))]
recipes_v_gf.loc[:, 'title']
# Out:
# 0                              Banana Blueberry Pancakes
# 1                Basil and Orange Confit Compound Butter
# 14                            Spicy Carrot Amaranth Soup
# 15                                            Nutty Rice
# 20                           Fire Roasted Tomato Chutney
# 22                                 Butternut Squash Soup
# 24                         Green Beans with Garlic Chips
# 27                                Easy Eggplant Parmesan
# 29                                            Kappa Maki
# 30                              Vegan Chana Masala Curry
# 31     Grilled Peach Melba with Vanilla Bean Frozen Y...
# 33                             Detox Orange Carrot Juice
# 37                      Roasted Asparagus with Egg Salad
# 39                   Three Ingredient Frozen Pina Colada
# 42                               Peach Coconut Ice Cream
# 57     Sautéed Balsamic Green Beans With Cherry Tomatoes
# ...

# %% [markdown]
# #### How many vegan recipes are there (Vegan = Vegetarian and dairy free)?

# %%
recipes_vegan = recipes.loc[((recipes['vegetarian'] == True) & (recipes['dairyFree'] == True))]
recipes_vegan.shape[0]
# Out:
# 29

# %% [markdown]
# #### Compare the average amount of Vitamin B12 for the vegan and non-vegan recipes. How reliable are the results?

# %%
recipes_vegan['VitaminB12Amount'].mean()

# VitaminB12Amount for vegan recipes
# Out:
# 0.24333333333333332

# %%
recipes_non_vegan = recipes.drop(recipes_vegan.index)
recipes_non_vegan['VitaminB12Amount'].mean()

# VitaminB12Amount for non-vegan recipes
# Out:
# 1.0345555555555552

# %% [markdown]
# #### Compare the average health Score for both types of recipes (vegan vs non-vegan).

# %%
recipes_vegan['healthScore'].mean()
# Out:
# 27.724137931034484

# %%
recipes_non_vegan['healthScore'].mean()
# Out:
# 18.785123966942148

# %% [markdown]
# #### Create a new column: "VeganWeek" where you decrease the price of vegan products by 10%, but only if they already cost more than 100.

# %%
recipes_vegan_100 = recipes_vegan[recipes_vegan.pricePerServing > 100]
recipes_vegan_100

recipes['VeganWeek'] = recipes_vegan_100['pricePerServing' ] - (0.1 * recipes_vegan_100['pricePerServing'])
recipes

# another solution to add new column -- recipes['VeganWeek'] = recipes_vegan.apply(lambda row: row.pricePerServing - (row.pricePerServing * 0.1), axis = 1)
# Out:
#      Unnamed: 0  vegetarian  glutenFree  dairyFree  veryHealthy  healthScore  \
# 0             0        True        True       True        False          1.0
# 1             1        True        True      False        False          0.0
# 2             2       False       False      False        False          3.0
# 3             3        True       False       True        False          2.0
# 4             4       False        True      False        False         31.0
# ..          ...         ...         ...        ...          ...          ...
# 145         145       False        True       True        False         18.0
# 146         146        True       False      False        False          1.0
# 147         147        True        True       True         True         93.0
# 148         148        True        True      False        False          5.0
# 149         149        True        True       True         True        100.0
#
#      aggregateLikes      id  \
# ...

# %% [markdown]
# #### Among the non-vegan recipes, find the one requiring most time to prepare. How is it called?

# %%
recipes_non_vegan[recipes_non_vegan['readyInMinutes']==recipes_non_vegan['readyInMinutes'].max()]
# Out:
#     Unnamed: 0  vegetarian  glutenFree  dairyFree  veryHealthy  healthScore  \
# 83          83       False       False      False        False          5.0
#
#     aggregateLikes     id              title  pricePerServing  ...  \
# 83               0  45945  Oeufs En Meurette           209.85  ...
#
#     VitaminB3Amount  VitaminB3percentOfDailyNeed VitaminB1Amount  \
# 83             1.51                         7.56            0.15
#
#     VitaminB1percentOfDailyNeed  CalciumAmount  CalciumpercentOfDailyNeed  \
# 83                        10.13         124.54                      12.45
#
#     AlcoholAmount  AlcoholpercentOfDailyNeed  CaffeineAmount  \
# 83            NaN                        NaN             NaN
#
#     CaffeinepercentOfDailyNeed
# 83                         NaN
#
# [1 rows x 79 columns]
